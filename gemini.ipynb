# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['GEMINI_API_KEY']= 'AIzaSyBP1vHReLfKqXzr5nW3q1Aj7vFq2nZTXiE'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])
# Out:
# C:\Users\Twinkele\AppData\Local\Temp\ipykernel_16360\3672976955.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')

# %%
response= model.generate_content("tabular format of the answer difference between ml ai and gen ai and agentic ai")
print(response.text)
# Out:
# To understand the relationship between these fields, it is best to view them as a hierarchy: **AI** is the broad field, **ML** is the core engine, **GenAI** is a creative capability, and **Agentic AI** is the application of reasoning and autonomy.
#
# ### Comparison Table
#
# | Feature | Artificial Intelligence (AI) | Machine Learning (ML) | Generative AI (GenAI) | Agentic AI |
# | :--- | :--- | :--- | :--- | :--- |
# | **Primary Definition** | The broad science of making machines "smart." | A subset of AI focused on systems that learn from data. | A subset of ML focused on creating *new* content. | An evolution of AI that acts autonomously to achieve goals. |
# | **Core Goal** | Simulate human intelligence. | Find patterns and make predictions. | Create new data (text, images, code). | Execute complex, multi-step tasks. |
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display

from IPython.display import Markdown

# %%
def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')

# %%
# %%time
response = model.generate_content(
    "Create a simple table to explain Data Science vs Machine Learning to a kid."
)
# Out:
# CPU times: total: 0 ns
# Wall time: 3.56 s

# %%
to_markdown(response.text)
# Out:
# > Here is a simple table to help explain the difference between Data Science and Machine Learning.
# >
# > Imagine **Data Science** is like being a **Detective**, and **Machine Learning** is like building a **Robot helper**.
# >
# > | Feature | Data Science (The Detective) | Machine Learning (The Robot Helper) |
# > | :--- | :--- | :--- |
# > | **Main Goal** | To find secrets and answers in data. | To learn how to do tasks on its own. |
# > | **What it does** | Asks questions and finds patterns. | Learns from patterns to make guesses. |
# > | **Example** | "Why do people buy ice cream more on hot days?" | "Predict how many ice creams we will sell tomorrow." |
# > | **The Result** | A report or a story with facts. | A smart program that gets better with practice. |
# >
# > ***
# >
# > ### A Simple Analogy:
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
    print(chunk.text)
# Out:
# Here is a simple table to help explain the difference between Data Science and Machine Learning.
#
# Imagine **Data Science** is like being a **Detective**, and **Machine Learning** is like building a **Robot helper**.
#
# | Feature | Data Science (The Detective) | Machine Learning (The Robot Helper) |
# | :--- | :--- | :--- |
# | **Main Goal** | To find secrets and answers in data. | To learn how to do tasks on its own. |
# | **What it does** | Asks questions and finds patterns. | Learns from patterns to make guesses. |
# | **Example** | "Why do people buy ice cream more on hot days?" | "Predict how many ice creams we will sell tomorrow." |
# | **The Result** | A report or a story with facts. | A smart program that gets better with practice. |
#
# ***
#
# ### A Simple Analogy:
# *   **Data Science** is like looking at a pile of your past test scores to figure out which subjects you are good at and which ones you need to study more. You are **learning information**.
# ...

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')
