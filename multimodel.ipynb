# %%
import PIL.Image

img = PIL.Image.open(r"C:\Users\Twinkele\OneDrive\Desktop\gemini ai model\modi.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x640>

# %%
import google.generativeai as genai
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')

# %%
import os
os.environ['GEMINI_API_KEY']= 'AIzaSyBP1vHReLfKqXzr5nW3q1Aj7vFq2nZTXiE'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown



def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > Based on the image provided, this is a meeting of the leaders of the **Quadrilateral Security Dialogue (Quad)**. From left to right, the individuals are:
# >
# > 1.  **Joe Biden**: President of the United States.
# > 2.  **Anthony Albanese**: Prime Minister of Australia.
# > 3.  **Fumio Kishida**: Then-Prime Minister of Japan.
# > 4.  **Narendra Modi**: Prime Minister of India.
# >
# > The Quad is a strategic security dialogue between these four nations that focuses on maintaining a free, open, and prosperous Indo-Pacific region.

# %%
import PIL.Image
img1 = PIL.Image.open(r'C:\Users\Twinkele\OneDrive\Desktop\2026-01-02\1000197438.jpg')

img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x576>

# %%
model = genai.GenerativeModel('models/gemini-3.1-pro-preview-customtools')

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown



def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img1)
to_markdown(response.text)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Twinkele\anaconda3\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\Twinkele\anaconda3\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)
#     274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
# ...

# %%
response = model.generate_content(["write a script for 5sec instagram shoot to gain good view",img], stream=True)
response.resolve()
